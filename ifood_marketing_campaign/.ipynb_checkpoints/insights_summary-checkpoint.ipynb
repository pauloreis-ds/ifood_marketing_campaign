# %% [markdown]
#         Here I gathered all relevant information I think may be useful to the business team.
#         Now, I'll analyse and choose what I need or want to show during the presentation.

# %% [markdown]
# <font color='grey'>Como os dados são uma amostra da base de dados. Sempre há a dúvida de se "o resultado é esse mesmo ou é derivado do viés ao escolher observações aleatórias?" Mas nada que aplicar o pipeline, com os passos que não necessitem das campanhas, no dataset completo não resolva.</font>

# %% [markdown]
# ## Predictive Model
# ### 5.0 Business Impact
#
# **Estimated Revenue for Next Campaign.**
#
# > Worst Scenario: R\\$ 15,675.73 <br>
# > **Expected:       R\\$ 17,390.27** <br>
# > Best Scenario:  R\\$ 19,104.80 <br>
# >
# > ___
# >
# > _"The total cost of the sample campaign was 6.720MU and the revenue generated_
# >
# > _by the customers who accepted the offer was 3.674MU. Globally the campaign_
# >
# > _had a profit of -3.046MU. The success rate of the campaign was 15%."_

# %%
# Model's
worst_detection_rate    = .64
expected_detection_rate = .71
best_detection_rate     = .78

campaign_cost    = 6720
customers        = 2240
campaign_revenue = 3674
success_rate     = .15
revenue_per_customer = campaign_revenue/(customers*success_rate)
acquisition_cost = campaign_cost/customers

# %%
def estimate_revenue(customers_quantity, target_detection_rate, revenue_per_customer):
    return (customers_quantity * target_detection_rate) * revenue_per_customer

print("Estimated Revenue for Next Campaign Scenarios.\n(Logistic Regression)")
print(f"Worst:    R$ {round( estimate_revenue(customers, worst_detection_rate,    revenue_per_customer), 2)}")
print(f"Expected: R$ {round( estimate_revenue(customers, expected_detection_rate, revenue_per_customer), 2)}")
print(f"Best:     R$ {round( estimate_revenue(customers, best_detection_rate,     revenue_per_customer), 2)}")
print()
print("Estimated Revenue for Next Campaign Scenarios.\n(Random Forest)")
print(f"Worst:    R$ {round( estimate_revenue(customers, .67,    revenue_per_customer), 2)}")
print(f"Expected: R$ {round( estimate_revenue(customers, .74,    revenue_per_customer), 2)}")
print(f"Best:     R$ {round( estimate_revenue(customers, .81,    revenue_per_customer), 2)}")
# Out:
# Estimated Revenue for Next Campaign Scenarios.
# (Logistic Regression)
# Worst:    R$ 15675.73
# Expected: R$ 17390.27
# Best:     R$ 19104.8
#
# Estimated Revenue for Next Campaign Scenarios.
# (Random Forest)
# Worst:    R$ 16410.53
# Expected: R$ 18125.07
# Best:     R$ 19839.6

# %%
profit = revenue_per_customer-acquisition_cost

print("Estimated Profit for Next Campaign Scenarios.\n(Logistic Regression)")
print(f"Worst:    R$ {round( estimate_revenue(customers, worst_detection_rate,    profit), 2)}")
print(f"Expected: R$ {round( estimate_revenue(customers, expected_detection_rate, profit), 2)}")
print(f"Best:     R$ {round( estimate_revenue(customers, best_detection_rate,     profit), 2)}")
print()
print("Estimated Profit for Next Campaign Scenarios.\n(Random Forest)")
print(f"Worst:    R$ {round( estimate_revenue(customers, .67,    profit), 2)}")
print(f"Expected: R$ {round( estimate_revenue(customers, .74,    profit), 2)}")
print(f"Best:     R$ {round( estimate_revenue(customers, .81,    profit), 2)}")
# Out:
# Estimated Profit for Next Campaign Scenarios.
# (Logistic Regression)
# Worst:    R$ 11374.93
# Expected: R$ 12619.07
# Best:     R$ 13863.2
#
# Estimated Profit for Next Campaign Scenarios.
# (Random Forest)
# Worst:    R$ 11908.13
# Expected: R$ 13152.27
# Best:     R$ 14396.4

# %% [markdown]
# ### Return On Investment

# %%
revenue_then = 3674
investment_cost = 6720
revenue_now = 17390.27
roi_then = (revenue_then - investment_cost) /investment_cost * 100
roi_now  = (revenue_now - investment_cost) /investment_cost * 100
print(f"Current ROI:   {roi_then}")
print(f"Estimated ROI: {roi_now} ")
# Out:
# Current ROI:   -45.32738095238095
# Estimated ROI: 158.78377976190475

# %% [markdown]
# # Analysis Results
#
#
#     "complain" rate (actually, if the customer complained in the last 2 years) seems pretty low (1%).
#     With 1 million clients, this means about 10 thousand complainings in 2 years, but to be sure if
#     thats good or not... it depends on the company metric and goal.
#
#
# ### 5.1.2. Numerical Variables
#
# > year_birth (age).
#
#     Most customers are between 30 and 60 years old.
#
# > income
#
#     Most customers have an yearly household income between 25,000 and 75,000
#
# > num_web_visits_month (Amount Spent).
#
#     Even though the amount spent tend to be low, the number of web visits tend to be high.
#     Probably because people look for food quite frequently in the website and buy it in little quantities.
#
# > dependents_number
#
#     Usually families have 1 dependent only  (a kid or a teen), as we also see in kidhome and teenhome.
#
# > num_accepted_cmps
#
#     70% of people who has accepted some campaign, has accepted only 1 of them. Then, after a campaign it's hard
#     for the person to accept another.
#
#
#
# ### _5.2.1. Type of Product._
#
# During descriptive statistics (1.5.1. Numerical Attributes) We saw positive skews, then let's use the median to calculate which type of products usually brings more revenue.
#
# - What type of product brings more revenue?
#
#         Wine. People usually spend more on wine, and then meat.
#         Gains are about 26 thousand each month (throughout the 2 years).
#
# <font color='blue'>**Actionable: We can focus on marketing to make wine sales stronger or to bring other products to the race. Either way we need other types of data to be more accurate about which path to follow.**</font>
#
# - Among those who accepted:
#
#         Same conclusion for those who accepted last campaign.
#         With those being responsible for about (R$ 6,400)
#         24% of wine monthly revenue.
#
# <img src='images/presentation/sum_revenues.png' width=600px>
#
# <img src='images/presentation/sum_revenues_table.jpg' width=200px>
#
#         People usually use 50% of what they spend on wine.
#         (This might be a lead to a future campaign, project or innovation)
#
# <img src='images/presentation/mean_percentage_spents.png' width=600px>
#
#
# - What type of product brings more revenue in web purchases?
# - What type of product brings more revenue in store purchases?
# - What type of product brings more revenue in catalog purchases?
# - What type of product brings more revenue in discount purchases?
#
# > _We can not answer those questions. We need data about where/how each product were bought. At the moment, they're all jointed, We know determined person spent about X in some product, but We don't know how did he get it. A query on the database (data lake) would probably solve this issue._
#
#
# ### _5.2.2. Type of Purchase._
#
# **_1. Web purchases bring more revenue than purchases made in stores._**
#
# > **No, store purchases usually have more gains.**
#
#     Probably because in the beginnig (2011 - 2014) people didn't trust the delivery service?
#
# **_How does this affects the company, in terms of revenue?_**
#
# > **The current expected month gains (for 2015) are about  R$ 170,000.**
# >
# > **(in the best case scenario)**
# >
# > **Store purchases are responsible for 44% of revenue**
# >
# > **(29% comes from Web)**
#
#         store_revenue_month:   75,638.53
#         web_revenue_month:     50,443.4
#         catalog_revenue_month: 44,975.89
#
# <font color='blue'>**Actionable: As the web conversion rate is 77% this might be a signal to attract more people to web plataform. However, without a rate to compare with... we can only start to collect the neccessary data to answer this in the future.**</font>
#
# <img src='images/presentation/web_store_revenue.png' width=700px>
#
#         It's important to note how I calculated the expected month gains:
#
#         mean_amount_spent_per_month = amount_spent / loyalty_time_months
#
#         As you can see, that approach comes with a problem, newcomers
#         present crazy values:
#
#         amount_spent  loyalty_time_months     per_month
#             1,254            0.16	            7,524
#               972            0.50	            1,944
#               909            0.60	            1,515
#             1,051	        0.20	            5,255
#
#         I solved this by keeping the whole value in months < 1, since
#         in most cases it made sense, as in:
#
#         amount_spent  loyalty_time_months     per_month
#                39            0.16	           keep 39
#                48            0.20	           keep 48
#
#         Then,
#
# > **With a more realistic approach, replacing those**
# >
# > **outliers, a better estimation is about R\$ 85,000.**
# >
# > What give us a revenue of about R\$ 42.5 for customer (each month).
# >
# > 85000/2000 = 45.2
#
#
# <img src='images/presentation/cumulative_revenue.png' width=850px>
#
#
# **_2. More discounts are made in Web purchases.._**
#
#     We need different data to say whether that hypothesis is right. Because we don't know if the discount purchases
#     were made through web, catalog or store.
#
#     18% of the purchases made have some discount.
#     ps: I can't tell if num_purchases is related to "2 years" as in MntFishProducts, MntMeatProducts, etc...
#
#
# **_3. More catalog purchases are made in Stores.._**
#
#     We also need different data to confirm this.
#
#     21% of purchases comes from catalogues.
#
# <img src='images/presentation/purchases_by_channels.png' width=550px>
#
# - Which type of purchase has higher "rates of acceptance" from last campaign (response)?
#
#         We can't answer that question, because we don't have information about what purchases
#         were made during each campaign.
#
#         But grouping the customers by the campaigns, the number of store purchases is always
#         the highest.
#
# > Response:
# >
# > **Store_purchases 40%**
# >
# > **Web_purchases 33%**
#
# ### _5.2.3. Customers._
#
#
# **_4. Older Customers tend to accept the campaign._**
#
# > **Yes. in the last campaign we can see that most <br>
# > customers are subscribed for longer**
# >
# > However, throughout the campaigns there are no trend.
#
#
# <img src='images/presentation/campaign_count_by_enrollment.png' width=700px>
#
#
# **_6. Customers with no complaints tend to accept the campaign._**
#
# > **Yes**, 99% of people who accepted the campaign hadn't complained.
# >
# > Though it's a really small amount of complaints (20).
#
# **_7. Customers with no complaints bring more revenue._**
#
# > **Yes.**
#
#
# **_8. Customers who buy more frequently tend to accept the campaign._**
#
#         No data about the frequency or dates of purchases.
#
# **_9. Customers who buy more frequently bring more revenue._**
#
#          No data about the frequency or dates of purchases.
#
#
# However, people who have made a purchase recently were prone to accept the campaign.
#
# <img src='images/presentation/accepted_recency.png' width=650px>
#
#
# **_10. Customers with higher income tend to accept the campaign._**
#
# > **Yes.** 61% of customers who accepted the campaign
# >
# > have an income value greater than the mean income.
#
#     And in terms of revenue, for those who accepted the campaign, the greater the income the greater the
#     amount spent.
#
# **_11. Customers with higher income bring more revenue._**
#
# > Yes, but this correlation is not as strong as expected.
# >
# > Which means that **in terms of revenue the difference**
# >
# > **may not be that large** (weak linear relationship).
#
#
# <img src='images/presentation/mean_amount_month_by_income.png' width=600px>
#
#
#
# **_12. Customers with greater educational level tend to accept the campaign._**
#
# > Yes, but not quite, half of people are graduated, then
# >
# > this imbalance in data kind of undo any possible trend.
# >
# > Using the percentage scale we can see there is a
# >
# > relation, but that doesn't mean the more PHDs higher
# >
# > the chance the customer will accept the campaign.
#
# <img src='images/presentation/accepted_education.png' width=600px>
#
# <img src='images/presentation/accepted_%_education.png' width=600px>
#
#
# **_13. Customers with greater educational level bring more revenue._**
#
# > Until a certain level we can say that's true.
# >
# > However, after gratuate, that's not a rule.
#
#     Customers with greater educational level tend to have greater amount_spent.
#
# <img src='images/presentation/spent_education.png' width=800px>
#
#
#
# **_14. Customers with two kids tend to accept the campaign._**
#
# > **No**, the more the kids the lower is the chance
# >
# > of acceptance.
#
#
# <img src='images/presentation/accepted_dependents.png' width=600px>
#
#
#
# **_15. Customers with two kids bring more revenue._**
#
# > **No,** again, the more the kids the lower is the revenue
#
#
#
# **_16. Single Customers tend to accept the campaign._**
#
# > **Yes**, they're not majority, yet more of them has accepted.
#
# <img src='images/presentation/marital_response.png' width=600px>
#
#
#
# **_17. Single Customers bring more revenue._**
#
# > **No**, though widows have the greatest average.
#
#
# - Which marital status has higher rates of acceptance of the last campaign?
#
#         Widow       27%
#         Single      23%
#         Divorced    20%
#         Married     12%
#         Together    11%
#
# - Which marital status has accepted more campaigns?
#
#         Married     244
#         Together    150
#         Single      135
#
# - Among those who accepted:
#
#         Married     106
#         Single       91
#         Together     51
#
#
#
# ### Conversion Rate.
# <font size=1>Second Cycle*</font>
#
# > **77% of web convertion rate**
# >
# > 8425 out of 10934 web visits ended up in a purchase.
#
# **Most Revenue Comes From? What do they buy the most? Work on that! _Coupon_**
#
# > Customers between 36 to 45. However, even though in fewer numbers,
# >
# > youngs (19 to 21) and elders (67 to 73) have the greatest spends
# >
# > by month. The older the person the higher the chance wine is the
# >
# > preference. While the young customers likes wine and meat at
# >
# > similar levels.
#
#
# <img src='images/presentation/spent_percentage_age.png' width=500px>
#
#
# ### Number of Dependents
# <font size=1>Second Cycle*</font>
#
# Even though there are almost the double quantity of customers with 1 dependent when compared to those who have no one, clients with no dependents bring more revenue (even in cumulative values).
#
#
# <img src='presentation/target_per_dependents.png' width=600px>
#
#
# > num_accepted_cmps
#
#     70% of people who has accepted some campaign, has accepted only 1 of them. Then, after a campaign it's hard
#     for the person to accept another.
#
# <font color='blue'>**Actionable: Which means that when getting people from database to apply to the model, it's important to choose those who hasn't been chosen for a while or the ones who has participated in at most 1.**</font>
#
# <img src='images/presentation/target_per_campaigns.png' width=600px>
#
#
# 79% of customers didn't accepted any previous campaign.
#
#         0    0.790370
#         1    0.147860
#         2    0.037451
#         3    0.019455
#         4    0.004864
#
# From those who accepted some campaign, 70% accepted only 1 of them.
#
#         1    0.705336
#         2    0.178654
#         3    0.092807
#         4    0.023202
#
# **The more the campaigns accepted, lower the chance they accept our target campaign.**
#
#         num_accepted_cmps
#         0    137
#         1     95
#         2     39
#         3     32
#         4      9
#
# _From customers who haven't accepted any of the 5 campaigns, 8% accepted only the target campaign._
#
#         Accepted 0 campaigns: 1625
#         and only our target campaign: 137
#
#         137 / 1625 =  0.08
#
# Those represent 43% of who accepted
#
# **43% of our target customers have accepted only the target campaign.**
#
#         total_acceptances = 312
#
#         137 / 312

# %% [markdown]
# ## Clustering
#
# Interesting Classes:
#
# - **targeted** - It concentrates more targets. **Segment of targets.**<br>
# - **untargeted** - It concentrates fewer targets. **Group we want to avoid (or work on with another marketing strategy)**<br>
# - **hidden_t** - It doesn't really give us any useful information for now.
#
#
#                    count  targets
#         hidden_t     800	17%
#         untargeted   799	05%
#         targeted     457	29%
#
# Blank means they are scattered throughout the axis.
#
# ### Recency
# _number of days since the last purchase_
#
# - **untargeted**
#         More than 48 days passed since last purchase
#
# <p float="left">
#     <img src='images/cluster/recency_income.jpg' width=350px/>
#     <img src='images/cluster/recency_boxplot.jpg' width=350px/>
# </p>
#
#
# ### Income
# _customer's yearly household income_
#
# - **targeted**
#         Over R$ 50,000
#
# <img src='images/cluster/income_boxplot.jpg' width=350px/>
#
#
# ### Amount Wines
# _amount spent on wines products in the last 2 years_
#
# - **targeted**
#         Over 455
# - **untargeted**
#         Under 455
# - **hidden_t**
#         Under 455
#
# <p float="left">
#     <img src="images/cluster/amount_wines_income.jpg" width=350px/>
#     <img src="images/cluster/amount_wines_recency.jpg" width=350px/>
#     <img src="images/cluster/amount_wine_boxplot.jpg" width=350px/>
# </p>
#
#
#
# ### Amount Fruits
# _amount spent on fruits products in the last 2 years_
#
# - **targeted, untargeted, hidden_t**
#         They are all scattered, but 75% of untargeted and hidden_t customers has bought fewer than 19 fruits.
#
# <img src="images/cluster/amount_fruits.jpg" width=950px/>
#
#
# ### Amount Meat
# _amount spent on meat products in the last 2 years_
#
#         The same as in Fruits (but fewer than 120 products).
#
# <img src="images/cluster/mnt_meat_products.jpg" width=650px/>
#
#
# ### Amount Fish
# _amount spent on fish products in the last 2 years_
#
#         75% of customers have bought a maximum of 28 products.
#
# <img src="images/cluster/mnt_fish.jpg" width=650px/>
#
#
# ### Amount Sweets
# _amount spent on sweet products in the last 2 years_
#
#         75% of customers have bought a maximum of 20 products.
#
# <img src="images/cluster/mnt_sweet.jpg" width=650px/>
#
#
# ### Amount Gold
# _amount spent on gold products in the last 2 years_
#
#         75% of customers have bought a maximum of 43 products.
#
# <img src="images/cluster/mnt_gold.jpg" width=650px/>
#
#
# ### Number of Purchases
# _total number of purchases made in the last 2 years_
#
# - **targeted**
#         They have bought more than 10 products i the last 2 years.
#
# <img src="images/cluster/num_purchases.jpg" width=650px/>
#
#
# ### Amount Spent
# _sum of spends made in the last 2 years_
#
# - **targeted**
#         They have spent over R$ 484
#
# <img src="images/cluster/amount_spent_income.jpg" width=350px/>
#
#
# ### mean_amount_spent_per_month
# _How much it's expected for the customer to spend each month he makes a purchase_
#
# - **targeted**
#         They spend at least R$ 27
#
# <img src="images/cluster/mean_amount_spent_per_month_wine.jpg" width=350px/>
#
#
# ## spent_percentage_fruits
# _percentage of amount spent in fruits_
#
# - **targeted**
#         They spend a maximum value of 16% of spending in fruits
#
# <img src="images/cluster/spent_percentage_fruits_wine.jpg" width=350px/>
#
#
# ### spent_percentage_fish
# _percentage of amount spent in fish products_
#
# - **targeted**
#         They spend a maximum value of 20% of spending in fish products
